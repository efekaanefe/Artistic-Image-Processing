# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from img2ascii import img2ascii
from thread_and_nails import thread_and_nails

# %%
images = ["marilyn-monroe.png", "simpsons.png", "spiderman.jpg", "mountains.jpg", "lily-collins.png"]
index = 0
image = cv2.imread(f"images\\{images[index]}")
print(image.shape)
plt.imshow(image)
plt.show()

img2ascii(image,
          output_width=100,
          save_path=None,
          original_colors=False,
          only_edges=True)

thread_and_nails(image,
                 num_nails=100,
                 num_threads=300,
                 save_path=None)
# Out:
# (465, 453, 3)
